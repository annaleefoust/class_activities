# %%
import pandas as pd

# %%
data = pd.read_excel(r'/Users/annaleefoust/Downloads/commerce_data.xlsx')

# %%
data
# Out:
#       product_price  discount  viewer   likes    sales
# 0             11700      0.29  650000  180000    11700
# 1             17400      0.44  650000  180000    87000
# 2             14000      0.47  650000  180000  8540000
# 3             29100      0.29  410000   18000  5063400
# 4             32000       NaN  350000   15000  1024000
# ...             ...       ...     ...     ...      ...
# 2898           1590      0.27    1271    4509    19080
# 2899           1390      0.26    1271    4509    31970
# 2900           1390      0.26    1271    4509   111200
# 2901            990      0.34    1271    4509   124740
# 2902          65000       NaN    1141    4155   195000
#
# [2903 rows x 5 columns]

# %%
data.shape
# Out:
# (2903, 5)

# %%
data.columns
# Out:
# Index(['product_price', 'discount', 'viewer', 'likes', 'sales'], dtype='object')

# %%
data['product_price']
# Out:
# 0       11700
# 1       17400
# 2       14000
# 3       29100
# 4       32000
#         ...
# 2898     1590
# 2899     1390
# 2900     1390
# 2901      990
# 2902    65000
# Name: product_price, Length: 2903, dtype: int64

# %%
data[data.columns[0]]
# Out:
# 0       11700
# 1       17400
# 2       14000
# 3       29100
# 4       32000
#         ...
# 2898     1590
# 2899     1390
# 2900     1390
# 2901      990
# 2902    65000
# Name: product_price, Length: 2903, dtype: int64

# %%
import seaborn as sn
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,5))

# %%
plt.figure(figsize=(7,5))
sn.scatterplot(data= data, x = "likes", y = 'sales')
# Out:
# <Axes: xlabel='likes', ylabel='sales'>

# %%
plt.figure(figsize=(7,5))
sn.scatterplot(data = data, x = "likes", y = "sales", color = "orange", marker = "s")
# Out:
# <Axes: xlabel='likes', ylabel='sales'>

# %%
plt.figure(figsize = (7,5))
x = sn.scatterplot(data = data, x = "likes", y = "sales", color = "orange", marker = "s", s = 100)

# %%
plt.figure(figsize = (7,5))
x = sn.scatterplot(data = data, x = "likes", y = "sales", color = "orange", marker = "s", s = 100)
x.set_xlabel("Likes", fontsize = 15)
x.set_ylabel("Sales", fontsize = 15)
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.figure(figsize = (10,10))
x = sn.scatterplot(data = data, x = "product_price", y = "discount", color = "pink", marker = "s", s = 90)
x.set_xlabel("product price", fontsize = 10)
x.set_ylabel("discount", fontsize = 10)
# Out:
# Text(0, 0.5, 'discount')

# %%
data['discount'] = data['discount'].fillna('0')

# %%
data
# Out:
#       product_price discount  viewer   likes    sales
# 0             11700     0.29  650000  180000    11700
# 1             17400     0.44  650000  180000    87000
# 2             14000     0.47  650000  180000  8540000
# 3             29100     0.29  410000   18000  5063400
# 4             32000        0  350000   15000  1024000
# ...             ...      ...     ...     ...      ...
# 2898           1590     0.27    1271    4509    19080
# 2899           1390     0.26    1271    4509    31970
# 2900           1390     0.26    1271    4509   111200
# 2901            990     0.34    1271    4509   124740
# 2902          65000        0    1141    4155   195000
#
# [2903 rows x 5 columns]

# %%
discount_category = []
for i in range(len(data)):
    if float(data['discount'][i]) > 0.5:
        discount_category.append("high")
    else:
        discount_category.append("low")

# %%
data['discount_category'] = discount_category

# %%
data
# Out:
#       product_price discount  viewer   likes    sales discount_category
# 0             11700     0.29  650000  180000    11700               low
# 1             17400     0.44  650000  180000    87000               low
# 2             14000     0.47  650000  180000  8540000               low
# 3             29100     0.29  410000   18000  5063400               low
# 4             32000        0  350000   15000  1024000               low
# ...             ...      ...     ...     ...      ...               ...
# 2898           1590     0.27    1271    4509    19080               low
# 2899           1390     0.26    1271    4509    31970               low
# 2900           1390     0.26    1271    4509   111200               low
# 2901            990     0.34    1271    4509   124740               low
# 2902          65000        0    1141    4155   195000               low
#
# [2903 rows x 6 columns]

# %%
plt.figure(figsize = (7,7))
sn.barplot(data = data, x = "discount_category", y = "sales")
# Out:
# <Axes: xlabel='discount_category', ylabel='sales'>

# %%
plt.figure(figsize = (7,7))
x = sn.barplot(data = data, x = "discount_category", y = "sales", errwidth = 0)
x.set_xlabel("Low or High Discount", fontsize = 15)
x.set_ylabel("Sales", fontsize = 15)
# Out:
# /var/folders/rg/4s22b8gn0tl0wd43d578xjh40000gn/T/ipykernel_30829/2328206577.py:2: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 0}` instead.
#
#   x = sn.barplot(data = data, x = "discount_category", y = "sales", errwidth = 0)
# Text(0, 0.5, 'Sales')

# %%
likes_category= []
for i in range(len(data)):
    if float(data['likes'][i]) > 10000:
        likes_category.append("high")
    else:
        likes_category.append("low")

# %%
data['likes_category'] = likes_category

# %%
plt.figure(figsize = (7,7))
x = sn.barplot(data = data, x = "likes_category", y = "discount")
x.set_xlabel("Low or High Like Count", fontsize = 15)
x.set_ylabel("Discount", fontsize = 15)
# Out:
# Text(0, 0.5, 'Discount')

# %%
sales_category = []

for i in range(len(data)):
    if int(data['sales'][i]) > 1000000:
        sales_category.append("good")
    else:
        sales_category.append("bad")

data['sales_category'] = sales_category

# %%
data
# Out:
#       product_price discount  viewer   likes    sales discount_category  \
# 0             11700     0.29  650000  180000    11700               low
# 1             17400     0.44  650000  180000    87000               low
# 2             14000     0.47  650000  180000  8540000               low
# 3             29100     0.29  410000   18000  5063400               low
# 4             32000        0  350000   15000  1024000               low
# ...             ...      ...     ...     ...      ...               ...
# 2898           1590     0.27    1271    4509    19080               low
# 2899           1390     0.26    1271    4509    31970               low
# 2900           1390     0.26    1271    4509   111200               low
# 2901            990     0.34    1271    4509   124740               low
# 2902          65000        0    1141    4155   195000               low
#
#      likes_category sales_category
# 0              high            bad
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
encoder = LabelEncoder()
encoder.fit(data['sales_category'])
data['sales_output'] = encoder.transform(data['sales_category'])
data
# Out:
#       product_price discount  viewer   likes    sales discount_category  \
# 0             11700     0.29  650000  180000    11700               low
# 1             17400     0.44  650000  180000    87000               low
# 2             14000     0.47  650000  180000  8540000               low
# 3             29100     0.29  410000   18000  5063400               low
# 4             32000        0  350000   15000  1024000               low
# ...             ...      ...     ...     ...      ...               ...
# 2898           1590     0.27    1271    4509    19080               low
# 2899           1390     0.26    1271    4509    31970               low
# 2900           1390     0.26    1271    4509   111200               low
# 2901            990     0.34    1271    4509   124740               low
# 2902          65000        0    1141    4155   195000               low
#
#      likes_category sales_category  sales_output
# 0              high            bad             0
# ...

# %%
encoder = LabelEncoder()
encoder.fit(data['discount_category'])
data['discount_binary'] = encoder.transform(data['discount_category'])
data
# Out:
#       product_price discount  viewer   likes    sales discount_category  \
# 0             11700     0.29  650000  180000    11700               low
# 1             17400     0.44  650000  180000    87000               low
# 2             14000     0.47  650000  180000  8540000               low
# 3             29100     0.29  410000   18000  5063400               low
# 4             32000        0  350000   15000  1024000               low
# ...             ...      ...     ...     ...      ...               ...
# 2898           1590     0.27    1271    4509    19080               low
# 2899           1390     0.26    1271    4509    31970               low
# 2900           1390     0.26    1271    4509   111200               low
# 2901            990     0.34    1271    4509   124740               low
# 2902          65000        0    1141    4155   195000               low
#
#      likes_category sales_category  sales_output  discount_binary
# ...

# %%
y = data['sales_output']
X = data[['discount_binary', 'likes']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, shuffle=True)
print(X_train.shape)
print(y_train.shape)
# Out:
# (2032, 2)
# (2032,)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#prediction based on the test data set
y_pred = model.predict(X_test)

#accuracy
accuracy = accuracy_score(y_test, y_pred)

#print the result
print(f"Accuracy: {accuracy: .2f}")
# Out:
# Accuracy:  0.77

# %%
model = LogisticRegression()
result = model.fit(X, y)

import numpy as np

def predict_good_prob(model, input_f):
    print('Prob', np.round(result.predict_proba(input_f)[:,1]*100,3))

newinput = [[1,100]]
predict_good_prob(result, newinput)
# Out:
# Prob [20.618]
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
